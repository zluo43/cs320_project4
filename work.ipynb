# %%
import pandas as pd
from flask import Flask, request, jsonify
import re
import numpy as np
import matplotlib.pyplot as plt

# %%
#f=pd.read_csv('main.csv')

# %%
#f.shape
# Out:
# (156, 9)

# %%
app = Flask(__name__)

counts = 1
countA = 0
countB = 0
email_n=0

@app.route('/')
def home():
    global counts

    while counts <11:
        if counts % 2==0:
            with open("index.html") as f:
                counts= counts+1
                htmlA = f.read()
                return htmlA

        else:
            with open("index.html") as f:
                counts= counts+1
                html = f.read()
                htmlB=html.replace('<li><a href="donate.html?from=A">donate</a>','<li><a href="donate.html?from=B">donateB</a>,<body style="background-color:lightgreen">')
                return htmlB
    
    else:
        if countA-countB >=0:
            with open("index.html") as f:
                html = f.read()
                htmlA=html.replace
                return htmlA

        else:
            with open("index.html") as f:
                html = f.read()
                htmlB=html.replace('<li><a href="donate.html?from=A">donate</a>','<li><a href="donate.html?from=B">donateB</a>,<body style="background-color:lightgreen">')
                return htmlB


@app.route('/browse.html')
def browse():
    main_csv = pd.read_csv("main.csv")
    return main_csv.to_html()     #html table 
   

@app.route('/email', methods=["POST"])
def email():
    global email_n
    
    email = str(request.data, "utf-8")
    suffix = r"\.(edu|com|org|net|io)"
    at = r"(@|[aA][tT][AT])"
    opt_brackets = r"[\(\)\{\}\[\]]?"
  
    if re.match(r"(\w+)\s*" + opt_brackets + at + opt_brackets + r"\s*(\w+)" + suffix, email): # 1
        with open("emails.txt", "a+") as f: # open file in append mode
            if email not in f:
                f.write(email + "\n")
            else:
                return jsonify("Sorry you are already a member")
            
            email_n=email_n+1
            
            
        return jsonify("thanks, you're subscriber number {}!".format(email_n))
    return jsonify("Invalid Email address") #3



@app.route('/donate.html')
def donate():
    
    with open("donate.html") as f:
        html = f.read()    
    if request.args.get("from")=="A":
        global countA
        countA=countA+1
        html=html.format(countA)

    else:
        global countB
        countB=countB+1
        html=html.format(countB)
    return html

# %%
import matplotlib.pyplot as plt
plt.rcParams["font.size"] = 16
f=pd.read_csv('main.csv')

rank=f['Overall rank']
country=f['Country or region']
perception_of _corruption=f['Perceptions of corruption']

@app2.route("/rank.svg")
def animal():
    fig, ax = plt.subplots()

    animal = request.args["type"]
    df[animal].plot.scatter(ylim=0, xlim=(2010, 2020), ax=ax)
    ax.set_xlabel("Year")
    ax.set_ylabel(f"{animal} Sightings")
    fake_file = BytesIO()
    ax.get_figure().savefig(fake_file, format="svg", bbox_inches="tight")
    return Response(fake_file.getvalue(),
                    headers={"Content-Type": "image/svg+xml"})

# %%
f
# Out:
#      Overall rank         Country or region  Score  GDP per capita  \
# 0               1                   Finland  7.769           1.340
# 1               2                   Denmark  7.600           1.383
# 2               3                    Norway  7.554           1.488
# 3               4                   Iceland  7.494           1.380
# 4               5               Netherlands  7.488           1.396
# ..            ...                       ...    ...             ...
# 151           152                    Rwanda  3.334           0.359
# 152           153                  Tanzania  3.231           0.476
# 153           154               Afghanistan  3.203           0.350
# 154           155  Central African Republic  3.083           0.026
# 155           156               South Sudan  2.853           0.306
#
#      Social support  Healthy life expectancy  Freedom to make life choices  \
# 0             1.587                    0.986                         0.596
# ...

# %%
4%2
# Out:
# 0
